# %%
import pandas as pd
import numpy as np
from pathlib import Path
from loguru import logger
from src.constants import EYE_BY_WORD_DF_L1_PATH, EYE_DF_L2_PATH
from typing import List, Union, Literal
import scipy.stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def lin_model_multi(data, eye_measure, readability_metrics):
    # Fit and summarize OLS model
    readability_diff_dict = {}
    eye_measure_diff = np.array(data[eye_measure + '_diff'])


    for r_metric in readability_metrics:
        readability_diff_dict[r_metric] = data[r_metric+"_diff"]

    X = pd.DataFrame.from_dict(readability_diff_dict)
    X = sm.add_constant(X)

    lin_model = sm.OLS(eye_measure_diff, X).fit()

    print(lin_model.summary())

# %%
def plot_scatter(data: pd.DataFrame, eye_measure: str, readability_measure: str, eye_measure_name: str):
    
    sns.regplot(x=readability_measure+"_diff", y=eye_measure+"_diff", data=data, x_bins=20)
    plt.title(f"{eye_measure_name} as function of {readability_measure}")
    plt.ylabel(eye_measure_name)
    plt.xlabel(readability_measure)
    plt.figure(constrained_layout=True)
    plt.show()

    g = sns.jointplot(x=readability_measure+"_diff", y=eye_measure+"_diff", data=data, kind='reg')
    # We're going to make the regression line red so it's easier to see
    regline = g.ax_joint.get_lines()[0]
    _ = regline.set_color('red')
    plt.show()

# %%
level = "sentence"
filtered = "_filtered"
not_filtered = ""

filtered = not_filtered

# %%
src_path = Path.cwd().parents[0]
path_to_df = src_path / Path(f"all_metrics/results/all_metrics_L1_gathering_1st_{level}{filtered}.csv")  

all_measures = pd.read_csv(path_to_df)
eye_measure = "SkipRateTotal"
metrics =  [
    'flesch_reading_ease',
    'flesch_kincaid_grade_score', 
    'gunning_fog_index', 
    'coleman_liau_index',
    'smog_index', 
    'dale_chall_score',
    'linsear_formula', 
    'ARI',
    'surprisal', 
    'CARES',
    'CAREC',
    'CAREC_M',
    'CML2RI']
lin_model_multi(all_measures, "TF", metrics)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     17.56
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           6.55e-36
# Time:                        05:37:41   Log-Likelihood:                -4039.4
# No. Observations:                 793   AIC:                             8107.
# Df Residuals:                     779   BIC:                             8172.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.1714      1.916     -0.089      0.929      -3.933       3.590
# flesch_reading_ease            1.5135      0.784      1.931      0.054      -0.025       3.052
# flesch_kincaid_grade_score   -11.3165      5.700     -1.985      0.047     -22.506      -0.127
# gunning_fog_index             -0.9772      1.114     -0.877      0.381      -3.164       1.210
# coleman_liau_index            -0.9132      2.085     -0.438      0.662      -5.007       3.181
# smog_index                    -0.1131      1.067     -0.106      0.916      -2.208       1.981
# dale_chall_score               0.1519      1.477      0.103      0.918      -2.748       3.052
# linsear_formula                0.9124      1.647      0.554      0.580      -2.320       4.145
# ARI                            5.2696      2.526      2.086      0.037       0.311      10.229
# surprisal                     20.1412      2.617      7.697      0.000      15.004      25.278
# CARES                         55.2823     27.949      1.978      0.048       0.418     110.147
# CAREC                         20.4325    124.049      0.165      0.869    -223.078     263.943
# CAREC_M                        5.8586    123.970      0.047      0.962    -237.495     249.213
# CML2RI                        -0.1365      0.469     -0.291      0.771      -1.057       0.784
# ==============================================================================
# Omnibus:                       17.171   Durbin-Watson:                   1.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               20.592
# Skew:                           0.270   Prob(JB):                     3.38e-05
# Kurtosis:                       3.575   Cond. No.                     2.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
src_path = Path.cwd().parents[0]
path_to_df = src_path / Path(f"all_metrics/results/all_metrics_L1_gathering_1st_{level}{filtered}.csv")  

all_measures = pd.read_csv(path_to_df)
eye_measure = "SkipRateTotal"
metrics =  [
    'flesch_reading_ease',
    'flesch_kincaid_grade_score', 
    'gunning_fog_index', 
    'coleman_liau_index',
    'smog_index', 
    'dale_chall_score',
    'linsear_formula', 
    'ARI',
    'surprisal', 
    'CARES',
    'CAREC',
    'CAREC_M',
    'CML2RI']
for metric in metrics:
    lin_model_multi(all_measures, "TF", [metric])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     41.50
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.05e-10
# Time:                        05:37:41   Log-Likelihood:                -4121.0
# No. Observations:                 793   AIC:                             8246.
# Df Residuals:                     791   BIC:                             8255.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   2.6968      1.891      1.426      0.154      -1.015       6.409
# flesch_reading_ease     0.6839      0.106      6.442      0.000       0.475       0.892
# ==============================================================================
# Omnibus:                       29.472   Durbin-Watson:                   1.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               62.561
# Skew:                           0.193   Prob(JB):                     2.60e-14
# Kurtosis:                       4.321   Cond. No.                         21.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     9.632
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):            0.00198
# Time:                        05:37:41   Log-Likelihood:                -4136.5
# No. Observations:                 793   AIC:                             8277.
# Df Residuals:                     791   BIC:                             8286.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          5.9187      1.986      2.980      0.003       2.020       9.818
# flesch_kincaid_grade_score     1.5133      0.488      3.104      0.002       0.556       2.470
# ==============================================================================
# Omnibus:                       39.254   Durbin-Watson:                   1.247
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.754
# Skew:                           0.269   Prob(JB):                     5.34e-20
# Kurtosis:                       4.548   Cond. No.                         5.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     7.427
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):            0.00657
# Time:                        05:37:41   Log-Likelihood:                -4137.6
# No. Observations:                 793   AIC:                             8279.
# Df Residuals:                     791   BIC:                             8289.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.4927      1.962      3.310      0.001       2.642      10.343
# gunning_fog_index     1.1783      0.432      2.725      0.007       0.330       2.027
# ==============================================================================
# Omnibus:                       39.410   Durbin-Watson:                   1.248
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.699
# Skew:                           0.276   Prob(JB):                     9.05e-20
# Kurtosis:                       4.533   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.096
# Method:                 Least Squares   F-statistic:                     85.22
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.39e-19
# Time:                        05:37:41   Log-Likelihood:                -4100.7
# No. Observations:                 793   AIC:                             8205.
# Df Residuals:                     791   BIC:                             8215.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  1.1358      1.773      0.641      0.522      -2.344       4.616
# coleman_liau_index     5.6625      0.613      9.232      0.000       4.458       6.867
# ==============================================================================
# Omnibus:                       28.000   Durbin-Watson:                   1.233
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.610
# Skew:                           0.138   Prob(JB):                     1.54e-14
# Kurtosis:                       4.360   Cond. No.                         3.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.05784
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):              0.810
# Time:                        05:37:41   Log-Likelihood:                -4141.3
# No. Observations:                 793   AIC:                             8287.
# Df Residuals:                     791   BIC:                             8296.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.6683      1.601      6.039      0.000       6.525      12.811
# smog_index     0.2587      1.076      0.240      0.810      -1.853       2.370
# ==============================================================================
# Omnibus:                       42.532   Durbin-Watson:                   1.239
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.700
# Skew:                           0.304   Prob(JB):                     2.73e-21
# Kurtosis:                       4.580   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.073
# Model:                            OLS   Adj. R-squared:                  0.072
# Method:                 Least Squares   F-statistic:                     62.12
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.07e-14
# Time:                        05:37:41   Log-Likelihood:                -4111.3
# No. Observations:                 793   AIC:                             8227.
# Df Residuals:                     791   BIC:                             8236.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                2.3422      1.793      1.306      0.192      -1.177       5.861
# dale_chall_score     8.0733      1.024      7.881      0.000       6.063      10.084
# ==============================================================================
# Omnibus:                       30.740   Durbin-Watson:                   1.245
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.446
# Skew:                           0.272   Prob(JB):                     9.12e-13
# Kurtosis:                       4.176   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.02014
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):              0.887
# Time:                        05:37:41   Log-Likelihood:                -4141.3
# No. Observations:                 793   AIC:                             8287.
# Df Residuals:                     791   BIC:                             8296.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               9.7842      1.915      5.110      0.000       6.026      13.543
# linsear_formula    -0.0472      0.333     -0.142      0.887      -0.700       0.606
# ==============================================================================
# Omnibus:                       42.624   Durbin-Watson:                   1.240
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               94.631
# Skew:                           0.306   Prob(JB):                     2.83e-21
# Kurtosis:                       4.578   Cond. No.                         6.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     18.02
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.45e-05
# Time:                        05:37:41   Log-Likelihood:                -4132.4
# No. Observations:                 793   AIC:                             8269.
# Df Residuals:                     791   BIC:                             8278.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.4965      1.988      2.262      0.024       0.595       8.398
# ARI            1.6851      0.397      4.245      0.000       0.906       2.464
# ==============================================================================
# Omnibus:                       39.035   Durbin-Watson:                   1.254
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.497
# Skew:                           0.266   Prob(JB):                     6.07e-20
# Kurtosis:                       4.548   Cond. No.                         6.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.174
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     166.4
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.08e-34
# Time:                        05:37:41   Log-Likelihood:                -4065.6
# No. Observations:                 793   AIC:                             8135.
# Df Residuals:                     791   BIC:                             8145.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2890      1.508      2.845      0.005       1.330       7.248
# surprisal     27.6469      2.143     12.900      0.000      23.440      31.854
# ==============================================================================
# Omnibus:                       37.295   Durbin-Watson:                   1.129
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.757
# Skew:                           0.413   Prob(JB):                     3.50e-12
# Kurtosis:                       3.956   Cond. No.                         1.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.057
# Method:                 Least Squares   F-statistic:                     49.28
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           4.77e-12
# Time:                        05:37:41   Log-Likelihood:                -4117.3
# No. Observations:                 793   AIC:                             8239.
# Df Residuals:                     791   BIC:                             8248.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.3986      1.859      1.290      0.197      -1.251       6.048
# CARES        142.0996     20.241      7.020      0.000     102.366     181.833
# ==============================================================================
# Omnibus:                       27.424   Durbin-Watson:                   1.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.420
# Skew:                           0.254   Prob(JB):                     5.05e-11
# Kurtosis:                       4.085   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     32.11
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.04e-08
# Time:                        05:37:41   Log-Likelihood:                -4125.5
# No. Observations:                 793   AIC:                             8255.
# Df Residuals:                     791   BIC:                             8264.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.1914      1.622      4.435      0.000       4.008      10.375
# CAREC         80.9174     14.280      5.666      0.000      52.886     108.949
# ==============================================================================
# Omnibus:                       30.156   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               47.120
# Skew:                           0.316   Prob(JB):                     5.86e-11
# Kurtosis:                       4.014   Cond. No.                         9.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     33.20
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.19e-08
# Time:                        05:37:41   Log-Likelihood:                -4125.0
# No. Observations:                 793   AIC:                             8254.
# Df Residuals:                     791   BIC:                             8263.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          7.3908      1.610      4.590      0.000       4.230      10.551
# CAREC_M       81.3968     14.127      5.762      0.000      53.666     109.127
# ==============================================================================
# Omnibus:                       29.993   Durbin-Watson:                   1.219
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.337
# Skew:                           0.318   Prob(JB):                     8.67e-11
# Kurtosis:                       3.999   Cond. No.                         9.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.048
# Model:                            OLS   Adj. R-squared:                  0.047
# Method:                 Least Squares   F-statistic:                     40.24
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           3.78e-10
# Time:                        05:37:41   Log-Likelihood:                -4121.6
# No. Observations:                 793   AIC:                             8247.
# Df Residuals:                     791   BIC:                             8257.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.2854      1.850      1.776      0.076      -0.346       6.916
# CML2RI         2.1783      0.343      6.344      0.000       1.504       2.852
# ==============================================================================
# Omnibus:                       34.347   Durbin-Watson:                   1.217
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.410
# Skew:                           0.238   Prob(JB):                     6.95e-17
# Kurtosis:                       4.423   Cond. No.                         6.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
src_path = Path.cwd().parents[0]
path_to_df = src_path / Path(f"all_metrics/results/all_metrics_L1_gathering_1st_{level}{filtered}.csv")  

all_measures = pd.read_csv(path_to_df)
eye_measure = "SkipRateTotal"
metrics = [
    'flesch_reading_ease',
    'flesch_kincaid_grade_score', 
    'gunning_fog_index', 
    'coleman_liau_index',
    'smog_index', 
    'dale_chall_score',
    'linsear_formula', 
    'ARI',
    'surprisal', 
    'CARES',
    'CAREC',
    'CAREC_M',
    'CML2RI']

for r_metric in metrics:
    plot_scatter(all_measures, "TF", r_metric, "total fixation")
