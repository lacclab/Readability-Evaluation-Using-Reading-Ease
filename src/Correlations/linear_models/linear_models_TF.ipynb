# %%
import pandas as pd
import numpy as np
from pathlib import Path
from loguru import logger
from src.constants import EYE_BY_WORD_DF_L1_PATH, EYE_DF_L2_PATH
from typing import List, Union, Literal
import scipy.stats
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def lin_model_multi(data, eye_measure, readability_metrics):
    # Fit and summarize OLS model
    readability_diff_dict = {}
    eye_measure_diff = np.array(data[eye_measure + '_diff'])


    for r_metric in readability_metrics:
        readability_diff_dict[r_metric] = data[r_metric+"_diff"]

    X = pd.DataFrame.from_dict(readability_diff_dict)
    X = sm.add_constant(X)

    lin_model = sm.OLS(eye_measure_diff, X).fit()

    print(lin_model.summary())

# %%
def plot_scatter(data: pd.DataFrame, eye_measure: str, readability_measure: str, eye_measure_name: str):
    
    sns.regplot(x=readability_measure+"_diff", y=eye_measure+"_diff", data=data, x_bins=20)
    plt.title(f"{eye_measure_name} as function of {readability_measure}")
    plt.ylabel(eye_measure_name)
    plt.xlabel(readability_measure)
    plt.figure(constrained_layout=True)
    plt.show()

    g = sns.jointplot(x=readability_measure+"_diff", y=eye_measure+"_diff", data=data, kind='reg')
    # We're going to make the regression line red so it's easier to see
    regline = g.ax_joint.get_lines()[0]
    _ = regline.set_color('red')
    plt.show()

# %%
level = "sentence"
filtered = "_filtered"
not_filtered = ""

# %%
src_path = Path.cwd().parents[0]
path_to_df = src_path / Path(f"all_metrics/results/all_metrics_L1_gathering_1st_{level}{filtered}.csv")  

all_measures = pd.read_csv(path_to_df)
eye_measure = "TF"
metrics =  [
    'flesch_reading_ease',
    'flesch_kincaid_grade_score', 
    'gunning_fog_index', 
    'coleman_liau_index',
    'smog_index', 
    'dale_chall_score',
    'linsear_formula', 
    'ARI',
    'surprisal', 
    'CARES',
    'CAREC',
    'CAREC_M',
    'CML2RI']
lin_model_multi(all_measures, "TF", metrics)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.216
# Method:                 Least Squares   F-statistic:                     17.78
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.22e-36
# Time:                        04:07:05   Log-Likelihood:                -4017.1
# No. Observations:                 793   AIC:                             8062.
# Df Residuals:                     779   BIC:                             8128.
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -0.4704      1.863     -0.252      0.801      -4.127       3.187
# flesch_reading_ease            1.3412      0.762      1.760      0.079      -0.155       2.837
# flesch_kincaid_grade_score    -9.8483      5.541     -1.777      0.076     -20.725       1.029
# gunning_fog_index             -0.8299      1.083     -0.766      0.444      -2.956       1.297
# coleman_liau_index            -0.7393      2.028     -0.365      0.716      -4.720       3.241
# smog_index                     0.0203      1.037      0.020      0.984      -2.016       2.057
# dale_chall_score               0.2026      1.436      0.141      0.888      -2.617       3.022
# linsear_formula                0.5995      1.601      0.374      0.708      -2.543       3.742
# ARI                            4.7020      2.456      1.915      0.056      -0.118       9.522
# surprisal                     19.9635      2.545      7.845      0.000      14.968      24.959
# CARES                         55.2560     27.176      2.033      0.042       1.909     108.602
# CAREC                         21.4473    120.613      0.178      0.859    -215.318     258.212
# CAREC_M                        2.6586    120.534      0.022      0.982    -233.952     239.269
# CML2RI                        -0.0898      0.456     -0.197      0.844      -0.985       0.805
# ==============================================================================
# Omnibus:                       15.703   Durbin-Watson:                   1.098
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.818
# Skew:                           0.253   Prob(JB):                     8.20e-05
# Kurtosis:                       3.561   Cond. No.                     2.50e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.5e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
src_path = Path.cwd().parents[0]
path_to_df = src_path / Path(f"all_metrics/results/all_metrics_L1_gathering_1st_{level}{filtered}.csv")  

all_measures = pd.read_csv(path_to_df)
eye_measure = "TF"
metrics =  [
    'flesch_reading_ease',
    'flesch_kincaid_grade_score', 
    'gunning_fog_index', 
    'coleman_liau_index',
    'smog_index', 
    'dale_chall_score',
    'linsear_formula', 
    'ARI',
    'surprisal', 
    'CARES',
    'CAREC',
    'CAREC_M',
    'CML2RI']
for metric in metrics:
    lin_model_multi(all_measures, "TF", [metric])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.051
# Model:                            OLS   Adj. R-squared:                  0.050
# Method:                 Least Squares   F-statistic:                     42.47
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.28e-10
# Time:                        04:07:05   Log-Likelihood:                -4099.4
# No. Observations:                 793   AIC:                             8203.
# Df Residuals:                     791   BIC:                             8212.
# Df Model:                           1
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   2.3469      1.840      1.275      0.203      -1.265       5.959
# flesch_reading_ease     0.6733      0.103      6.517      0.000       0.471       0.876
# ==============================================================================
# Omnibus:                       32.844   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               74.994
# Skew:                           0.198   Prob(JB):                     5.19e-17
# Kurtosis:                       4.453   Cond. No.                         21.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     9.692
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):            0.00192
# Time:                        04:07:05   Log-Likelihood:                -4115.3
# No. Observations:                 793   AIC:                             8235.
# Df Residuals:                     791   BIC:                             8244.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          5.5480      1.934      2.869      0.004       1.751       9.345
# flesch_kincaid_grade_score     1.4780      0.475      3.113      0.002       0.546       2.410
# ==============================================================================
# Omnibus:                       43.983   Durbin-Watson:                   1.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.769
# Skew:                           0.281   Prob(JB):                     3.96e-24
# Kurtosis:                       4.716   Cond. No.                         5.22
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     7.547
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):            0.00615
# Time:                        04:07:05   Log-Likelihood:                -4116.4
# No. Observations:                 793   AIC:                             8237.
# Df Residuals:                     791   BIC:                             8246.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                 6.0935      1.910      3.190      0.001       2.344       9.843
# gunning_fog_index     1.1565      0.421      2.747      0.006       0.330       1.983
# ==============================================================================
# Omnibus:                       44.009   Durbin-Watson:                   1.250
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              105.842
# Skew:                           0.288   Prob(JB):                     1.04e-23
# Kurtosis:                       4.694   Cond. No.                         5.70
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.098
# Model:                            OLS   Adj. R-squared:                  0.097
# Method:                 Least Squares   F-statistic:                     85.93
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.73e-19
# Time:                        04:07:05   Log-Likelihood:                -4079.3
# No. Observations:                 793   AIC:                             8163.
# Df Residuals:                     791   BIC:                             8172.
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.8710      1.726      0.505      0.614      -2.516       4.258
# coleman_liau_index     5.5342      0.597      9.270      0.000       4.362       6.706
# ==============================================================================
# Omnibus:                       30.607   Durbin-Watson:                   1.231
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               73.971
# Skew:                           0.139   Prob(JB):                     8.66e-17
# Kurtosis:                       4.470   Cond. No.                         3.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.1297
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):              0.719
# Time:                        04:07:05   Log-Likelihood:                -4120.1
# No. Observations:                 793   AIC:                             8244.
# Df Residuals:                     791   BIC:                             8254.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          9.2267      1.559      5.919      0.000       6.167      12.287
# smog_index     0.3772      1.047      0.360      0.719      -1.679       2.433
# ==============================================================================
# Omnibus:                       47.643   Durbin-Watson:                   1.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              115.121
# Skew:                           0.318   Prob(JB):                     1.00e-25
# Kurtosis:                       4.755   Cond. No.                         1.50
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     63.87
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           4.69e-15
# Time:                        04:07:05   Log-Likelihood:                -4089.4
# No. Observations:                 793   AIC:                             8183.
# Df Residuals:                     791   BIC:                             8192.
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.9842      1.744      1.138      0.256      -1.439       5.407
# dale_chall_score     7.9634      0.996      7.992      0.000       6.008       9.919
# ==============================================================================
# Omnibus:                       35.115   Durbin-Watson:                   1.243
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               67.964
# Skew:                           0.288   Prob(JB):                     1.75e-15
# Kurtosis:                       4.313   Cond. No.                         2.27
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                   0.04462
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):              0.833
# Time:                        04:07:05   Log-Likelihood:                -4120.1
# No. Observations:                 793   AIC:                             8244.
# Df Residuals:                     791   BIC:                             8254.
# Df Model:                           1
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               9.3945      1.864      5.039      0.000       5.735      13.054
# linsear_formula    -0.0684      0.324     -0.211      0.833      -0.704       0.568
# ==============================================================================
# Omnibus:                       47.778   Durbin-Watson:                   1.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              114.997
# Skew:                           0.321   Prob(JB):                     1.07e-25
# Kurtosis:                       4.752   Cond. No.                         6.97
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.021
# Method:                 Least Squares   F-statistic:                     17.62
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           3.00e-05
# Time:                        04:07:05   Log-Likelihood:                -4111.4
# No. Observations:                 793   AIC:                             8227.
# Df Residuals:                     791   BIC:                             8236.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.2283      1.936      2.184      0.029       0.428       8.029
# ARI            1.6231      0.387      4.198      0.000       0.864       2.382
# ==============================================================================
# Omnibus:                       43.651   Durbin-Watson:                   1.256
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              107.288
# Skew:                           0.277   Prob(JB):                     5.04e-24
# Kurtosis:                       4.715   Cond. No.                         6.41
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.176
# Model:                            OLS   Adj. R-squared:                  0.175
# Method:                 Least Squares   F-statistic:                     169.4
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           3.11e-35
# Time:                        04:07:05   Log-Likelihood:                -4043.2
# No. Observations:                 793   AIC:                             8090.
# Df Residuals:                     791   BIC:                             8100.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.9477      1.465      2.694      0.007       1.071       6.824
# surprisal     27.1383      2.085     13.016      0.000      23.045      31.231
# ==============================================================================
# Omnibus:                       37.455   Durbin-Watson:                   1.116
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.068
# Skew:                           0.401   Prob(JB):                     1.10e-12
# Kurtosis:                       4.011   Cond. No.                         1.58
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     50.50
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.66e-12
# Time:                        04:07:05   Log-Likelihood:                -4095.6
# No. Observations:                 793   AIC:                             8195.
# Df Residuals:                     791   BIC:                             8205.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.0501      1.809      1.133      0.257      -1.501       5.601
# CARES        139.9615     19.695      7.106      0.000     101.300     178.623
# ==============================================================================
# Omnibus:                       30.602   Durbin-Watson:                   1.231
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.969
# Skew:                           0.265   Prob(JB):                     7.02e-13
# Kurtosis:                       4.188   Cond. No.                         13.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.039
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     32.01
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.15e-08
# Time:                        04:07:05   Log-Likelihood:                -4104.4
# No. Observations:                 793   AIC:                             8213.
# Df Residuals:                     791   BIC:                             8222.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.8019      1.579      4.307      0.000       3.702       9.902
# CAREC         78.6726     13.906      5.657      0.000      51.376     105.969
# ==============================================================================
# Omnibus:                       34.296   Durbin-Watson:                   1.218
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               57.483
# Skew:                           0.330   Prob(JB):                     3.29e-13
# Kurtosis:                       4.142   Cond. No.                         9.14
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                  0.039
# Method:                 Least Squares   F-statistic:                     33.11
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           1.25e-08
# Time:                        04:07:05   Log-Likelihood:                -4103.9
# No. Observations:                 793   AIC:                             8212.
# Df Residuals:                     791   BIC:                             8221.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          6.9953      1.568      4.462      0.000       3.918      10.073
# CAREC_M       79.1545     13.756      5.754      0.000      52.151     106.158
# ==============================================================================
# Omnibus:                       34.153   Durbin-Watson:                   1.219
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.610
# Skew:                           0.333   Prob(JB):                     5.10e-13
# Kurtosis:                       4.127   Cond. No.                         9.05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.050
# Model:                            OLS   Adj. R-squared:                  0.049
# Method:                 Least Squares   F-statistic:                     41.46
# Date:                Wed, 30 Oct 2024   Prob (F-statistic):           2.09e-10
# Time:                        04:07:05   Log-Likelihood:                -4099.9
# No. Observations:                 793   AIC:                             8204.
# Df Residuals:                     791   BIC:                             8213.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.9069      1.800      1.615      0.107      -0.626       6.440
# CML2RI         2.1512      0.334      6.439      0.000       1.495       2.807
# ==============================================================================
# Omnibus:                       39.623   Durbin-Watson:                   1.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               92.901
# Skew:                           0.258   Prob(JB):                     6.71e-21
# Kurtosis:                       4.596   Cond. No.                         6.47
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
src_path = Path.cwd().parents[0]
path_to_df = src_path / Path(f"all_metrics/results/all_metrics_L1_gathering_1st_{level}{filtered}.csv")  

all_measures = pd.read_csv(path_to_df)
eye_measure = "TF"
metrics = [
    'flesch_reading_ease',
    'flesch_kincaid_grade_score', 
    'gunning_fog_index', 
    'coleman_liau_index',
    'smog_index', 
    'dale_chall_score',
    'linsear_formula', 
    'ARI',
    'surprisal', 
    'CARES',
    'CAREC',
    'CAREC_M',
    'CML2RI']

for r_metric in metrics:
    plot_scatter(all_measures, "TF", r_metric, "total fixation")
